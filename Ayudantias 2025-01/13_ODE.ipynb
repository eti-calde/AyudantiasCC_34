# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# supongamos que
# $$
# y''(x) = f(x) = cos(x)
# $$
#
# entonces y(x) = -cos(x) + C1x + C2

# %%
N = 100
L = 2 * np.pi
h = L / N

x = np.linspace(0, L, N, endpoint=False)

f = np.cos(x)

A = np.zeros((N, N))
for i in range(N):
    A[i, i] = -2
    A[i, (i - 1) % N] = 1
    A[i, (i + 1) % N] = 1

b = f * h**2
y = np.linalg.solve(A, b)

print(sum(y))
plt.plot(x, y+C, label='Aproximación numérica')
plt.plot(x, -np.cos(x), '--', label='Solución exacta: -cos(x)')
plt.title('Solución periódica de y\'\' = -cos(x)')
plt.legend()
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y(x)')
plt.show()
# Out:
# -1158.7411338344475
